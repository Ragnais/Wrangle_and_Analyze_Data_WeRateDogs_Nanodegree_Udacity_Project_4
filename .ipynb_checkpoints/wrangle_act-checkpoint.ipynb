# %% [markdown]
# ## Udacity Project:
#
# ## Wrangle and Analyze Data WeRateDogs

# %% [markdown]
# ### Introduction
#
#
# The tasks in this project are as follows:
#
# I. Data wrangling, which consists of:
#
#       1.Gathering data;
#       2.Assessing data;
#       3.Cleaning data.
#
# II. Storing, analyzing, and visualizing the wrangled data;
#
# III. Reporting on:
#
#         1.The data wrangle_report.pdf;
#         2.The data analyses and visualizations act_report.pdf.

# %% [markdown]
# Part I. Data wrangling
#
# ### 1.Gathering data
#
# Gather each of the three pieces of data:
#
# 1. twitter_archive_enhanced.csv - the WeRateDogs Twitter archive;
#
# 2. image_predictions.tsv - the tweet image predictions. The file can be downloaded programmatically using the Requests library and the following URL: https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv
#
# 3. Each tweet's retweet count and favorite ("like") count at minimum, and any additional data we find interesting. Using the tweet IDs in the WeRateDogs Twitter archive, we query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file. Each tweet's JSON data should be written to its own line. Then we read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count.

# %%
#Import the libraries
import numpy as np
import pandas as pd
import requests
import tweepy
import json
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline

# %%
#Read the csv file
df_tw_archive = pd.read_csv('twitter-archive-enhanced.csv')

# %%
#Read the tsv file

url="https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
url_data = requests.get(url)

with open('image_predictions.tsv', 'wb') as file:
    file.write(url_data.content)

# Read in tsv file as a Pandas DataFrame    
image_predictions = pd.read_csv('image_predictions.tsv', sep='\t', encoding = 'utf-8')

# %%
#API keys
consumer_key = ''
consumer_secret = ''
access_token = ''
access_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit = True, wait_on_rate_limit_notify = True)

# %%
# For loop 
with open('tweet-json.txt', 'a', encoding='utf8') as f:
    for tweet_id in df_tw_archive['tweet_id']:
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            json.dump(tweet._json, f)
            f.write('\n')
        except:
            continue
# Out:
# Rate limit reached. Sleeping for: 738
# Rate limit reached. Sleeping for: 737

# %%
#For loop to append each tweet into a list
tweets_data = []

tweet_file = open('tweet-json.txt', "r")

for line in tweet_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue
        
tweet_file.close()

# %%
# Create tweet_info DataFrame
tweet_info = pd.DataFrame()

# %%
# Add selected variables to tweet_info DataFrame
tweet_info['id'] = list(map(lambda tweet: tweet['id'], tweets_data))
tweet_info['retweet_count'] = list(map(lambda tweet: tweet['retweet_count'], tweets_data))
tweet_info['favorite_count'] = list(map(lambda tweet: tweet['favorite_count'], tweets_data))

# %% [markdown]
# ### 2.Assessing data

# %% [markdown]
# ##### df_tw_archive

# %%
# One column Dogtionary for doggo, floofer, pupper, puppo - the column names have variable
df_tw_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df_tw_archive['doggo'].unique()
df_tw_archive['floofer'].unique()
df_tw_archive['pupper'].unique()
df_tw_archive['puppo'].unique()
# Out:
# array(['None', 'puppo'], dtype=object)

# %%
df_tw_archive.tail(40)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2316  666649482315059201                    NaN                  NaN
# 2317  666644823164719104                    NaN                  NaN
# 2318  666454714377183233                    NaN                  NaN
# 2319  666447344410484738                    NaN                  NaN
# 2320  666437273139982337                    NaN                  NaN
# 2321  666435652385423360                    NaN                  NaN
# 2322  666430724426358785                    NaN                  NaN
# 2323  666428276349472768                    NaN                  NaN
# 2324  666421158376562688                    NaN                  NaN
# 2325  666418789513326592                    NaN                  NaN
# 2326  666411507551481857                    NaN                  NaN
# 2327  666407126856765440                    NaN                  NaN
# 2328  666396247373291520                    NaN                  NaN
# ...

# %%
#Column Name include invalid names "a", "an", "None", "the",'O', 'my', 'Al' etc.
df_tw_archive['name'].value_counts()
df_tw_archive[df_tw_archive['name'].str.len() < 3]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881536004380872706                    NaN                  NaN
# 393   825876512159186944                    NaN                  NaN
# 446   819015337530290176                    NaN                  NaN
# 449   819004803107983360                    NaN                  NaN
# 553   804026241225523202                    NaN                  NaN
# 583   800188575492947969                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 679   789137962068021249                    NaN                  NaN
# 686   788070120937619456                    NaN                  NaN
# 759   778396591732486144                    NaN                  NaN
# 775   776201521193218049                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# 820   770414278348247044                    NaN                  NaN
# ...

# %%
# Replace 'my' with the name 'Zoey'
my = df_tw_archive[df_tw_archive['name'] == 'my'].count()
print(my)
# Replace 'Al' with the name 'Al Cabone'
Al = df_tw_archive[df_tw_archive['name'] == 'Al'].count()
print(Al)
# Replace 'O' with the name 'O'Malley'
O = df_tw_archive[df_tw_archive.name == "O"].count()
print(O)
# Out:
# tweet_id                      1
# in_reply_to_status_id         0
# in_reply_to_user_id           0
# timestamp                     1
# source                        1
# text                          1
# retweeted_status_id           0
# retweeted_status_user_id      0
# retweeted_status_timestamp    0
# expanded_urls                 1
# rating_numerator              1
# rating_denominator            1
# name                          1
# doggo                         1
# floofer                       1
# pupper                        1
# puppo                         1
# dtype: int64
# tweet_id                      1
# in_reply_to_status_id         0
# in_reply_to_user_id           0
# timestamp                     1
# source                        1
# text                          1
# retweeted_status_id           0
# retweeted_status_user_id      0
# retweeted_status_timestamp    0
# expanded_urls                 1
# rating_numerator              1
# ...

# %%
df_tw_archive.name.sort_values()
# Out:
# 1035            Abby
# 1021            Abby
# 938              Ace
# 1933            Acro
# 1327           Adele
# 1934           Aiden
# 77               Aja
# 480            Akumi
# 820               Al
# 875           Albert
# 1954          Albert
# 144            Albus
# 412            Albus
# 1115         Aldrick
# 2046       Alejandro
# 374        Alexander
# 1189    Alexanderson
# 486              Alf
# 2238           Alfie
# 661            Alfie
# 367            Alfie
# 1616           Alfie
# 858            Alfie
# 51              Alfy
# 201            Alice
# 1701           Alice
# 1495           Amber
# 1334         Ambrose
# 2078             Amy
# 2195          Amélie
#             ...
# 852               my
# 988              not
# 335              not
# 1747      officially
# 1206             old
# 993              one
# 1936             one
# 924              one
# 369              one
# 2326           quite
# 169            quite
# 118            quite
# ...

# %%
#The value started with lowercase is not the name of a dog
#View rows where the value of 'name' is "a", "an", "the" and the word 'named' appears in the 'text' column.
#This indicates that there is an actual dog name in the 'text' which can be retrieved and replaced into col.'name'
lower_named = df_tw_archive.loc[(df_tw_archive['name'].str.islower()) & (df_tw_archive['text'].str.contains('named'))].count()
lower_nameis = df_tw_archive.loc[(df_tw_archive['name'].str.islower()) & (df_tw_archive['text'].str.contains('name is'))].count()
print(lower_named)
print(lower_nameis)
# Out:
# tweet_id                      20
# in_reply_to_status_id          0
# in_reply_to_user_id            0
# timestamp                     20
# source                        20
# text                          20
# retweeted_status_id            0
# retweeted_status_user_id       0
# retweeted_status_timestamp     0
# expanded_urls                 20
# rating_numerator              20
# rating_denominator            20
# name                          20
# doggo                         20
# floofer                       20
# pupper                        20
# puppo                         20
# dtype: int64
# tweet_id                      2
# in_reply_to_status_id         0
# in_reply_to_user_id           0
# timestamp                     2
# source                        2
# text                          2
# retweeted_status_id           0
# retweeted_status_user_id      0
# retweeted_status_timestamp    0
# expanded_urls                 2
# rating_numerator              2
# ...

# %%
#View rows where the value of 'name' is  "None" and the word 'named' appears in the 'text' column.
# This indicates that there is an actual dog name in the 'text' which can be retrieved and replaced into col.'name'

none_named = df_tw_archive.loc[(df_tw_archive['name'] == 'None') &   (df_tw_archive['text'].str.contains('named'))].count()
none_nameis = df_tw_archive.loc[(df_tw_archive['name'] == 'None') &   (df_tw_archive['text'].str.contains('name is'))].count()
print(none_named)
print(none_nameis)
# Out:
# tweet_id                      4
# in_reply_to_status_id         0
# in_reply_to_user_id           0
# timestamp                     4
# source                        4
# text                          4
# retweeted_status_id           1
# retweeted_status_user_id      1
# retweeted_status_timestamp    1
# expanded_urls                 4
# rating_numerator              4
# rating_denominator            4
# name                          4
# doggo                         4
# floofer                       4
# pupper                        4
# puppo                         4
# dtype: int64
# tweet_id                      6
# in_reply_to_status_id         1
# in_reply_to_user_id           1
# timestamp                     6
# source                        6
# text                          6
# retweeted_status_id           0
# retweeted_status_user_id      0
# retweeted_status_timestamp    0
# expanded_urls                 5
# rating_numerator              6
# ...

# %%
df_tw_archive.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
# The urls are not readable for human and the most favorable is iPhone
df_tw_archive.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
# These ratings should always have a denominator of 10. There are other denominators than 10 - Invalid values
df_tw_archive['rating_denominator'].value_counts()
df_tw_archive[df_tw_archive['rating_denominator'] != 10].count()
# Out:
# tweet_id                      23
# in_reply_to_status_id          5
# in_reply_to_user_id            5
# timestamp                     23
# source                        23
# text                          23
# retweeted_status_id            1
# retweeted_status_user_id       1
# retweeted_status_timestamp     1
# expanded_urls                 19
# rating_numerator              23
# rating_denominator            23
# name                          23
# doggo                         23
# floofer                       23
# pupper                        23
# puppo                         23
# dtype: int64

# %%
#The numerators should be almost always greater than 10. There are numerators lesss than 10 - Invalid values
df_tw_archive['rating_numerator'].value_counts()
df_tw_archive[df_tw_archive['rating_numerator'] < 10].count()
# Out:
# tweet_id                      440
# in_reply_to_status_id          12
# in_reply_to_user_id            12
# timestamp                     440
# source                        440
# text                          440
# retweeted_status_id             9
# retweeted_status_user_id        9
# retweeted_status_timestamp      9
# expanded_urls                 430
# rating_numerator              440
# rating_denominator            440
# name                          440
# doggo                         440
# floofer                       440
# pupper                        440
# puppo                         440
# dtype: int64

# %%
pd.set_option('display.max_colwidth', -1)
df_tw_archive[df_tw_archive['rating_denominator'] != 10]['text']
#313 13/10 second pos
#1068 14/10 second pos
#1165 13/10 second pos
#1202 11/10 second pos
#1662 10/10 second pos
#2335 9/10 second pos
#To retrieve the second pos as a rating and change denominator and numerator correspondingly
# Out:
# 313     @jonnysun @Lin_Manuel ok jomny I know you're excited but 960/00 isn't a valid rating, 13/10 is tho
# 342     @docmisterio account started on 11/15/15
# 433     The floofs have been released I repeat the floofs have been released. 84/70 https://t.co/NIYC820tmd
# 516     Meet Sam. She smiles 24/7 &amp; secretly aspires to be a reindeer. \nKeep Sam smiling by clicking and sharing this link:\nhttps://t.co/98tB8y7y7t https://t.co/LouL5vdvxx
# 784     RT @dog_rates: After so many requests, this is Bretagne. She was the last surviving 9/11 search dog, and our second ever 14/10. RIP https:/…
# 902     Why does this never happen at my front door... 165/150 https://t.co/HmwrdfEfUE
# 1068    After so many requests, this is Bretagne. She was the last surviving 9/11 search dog, and our second ever 14/10. RIP https://t.co/XAVDNDaVgQ
# 1120    Say hello to this unbelievably well behaved squad of doggos. 204/170 would try to pet all at once https://t.co/yGQI3He3xv
# ...

# %%
#There are incorrect data type for timestamp and retweeted_status_timestamp – should be datetime
df_tw_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
#There are no duplicates
df_tw_archive.duplicated().sum()
# Out:
# 0

# %%
#There are Missing values.
df_tw_archive.isnull().sum()
# Out:
# tweet_id                      0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                     0
# source                        0
# text                          0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                 59
# rating_numerator              0
# rating_denominator            0
# name                          0
# doggo                         0
# floofer                       0
# pupper                        0
# puppo                         0
# dtype: int64

# %%
# We do not want to have retweeted
df_tw_archive['retweeted_status_id'].notnull().sum()
# Out:
# 181

# %% [markdown]
# ##### image_predictions

# %%
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0  1        Welsh_springer_spaniel  0.465074  True    collie
# 1  1        redbone                 0.506826  True    miniature_pinscher
# 2  1        German_shepherd         0.596461  True    malinois
# 3  1        Rhodesian_ridgeback     0.408143  True    redbone
# 4  1        miniature_pinscher      0.560311  True    Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665  True    Shetland_sheepdog    0.061428  True
# ...

# %%
#The p1,p2 and p3 include Uppercase and Lowercase for the first letter
image_predictions.tail()
# Out:
#                 tweet_id                                          jpg_url  \
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2070  2        basset       0.555712  True    English_springer    0.225770
# 2071  1        paper_towel  0.170278  False   Labrador_retriever  0.168086
# 2072  1        Chihuahua    0.716012  True    malamute            0.078253
# 2073  1        Chihuahua    0.323581  True    Pekinese            0.090647
# 2074  1        orange       0.097049  False   bagel               0.085851
#
#       p2_dog                           p3   p3_conf  p3_dog
# ...

# %%
image_predictions.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17  1.203855     0.594548     1.345886e-01  6.032417e-02
# std    6.785203e+16  0.561875     0.271174     1.006657e-01  5.090593e-02
# min    6.660209e+17  1.000000     0.044333     1.011300e-08  1.740170e-10
# 25%    6.764835e+17  1.000000     0.364412     5.388625e-02  1.622240e-02
# 50%    7.119988e+17  1.000000     0.588230     1.181810e-01  4.944380e-02
# 75%    7.932034e+17  1.000000     0.843855     1.955655e-01  9.180755e-02
# max    8.924206e+17  4.000000     1.000000     4.880140e-01  2.734190e-01

# %%
#The data types seems good
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
#No Missing values
image_predictions.isnull().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %%
#No duplicates
image_predictions.duplicated().sum()
# Out:
# 0

# %%
image_predictions.duplicated(subset=['jpg_url']).sum()
# Out:
# 66

# %%
#There are duplicated url adresses
image_predictions['jpg_url'].duplicated().any()
# Out:
# True

# %%
image_predictions[image_predictions['jpg_url'] == 'https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg']
# Out:
#              tweet_id                                          jpg_url  \
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
#
#    img_num       p1   p1_conf  p1_dog                  p2   p2_conf  p2_dog  \
# 1  1        redbone  0.506826  True    miniature_pinscher  0.074192  True
#
#                     p3  p3_conf  p3_dog
# 1  Rhodesian_ridgeback  0.07201  True

# %%
image_predictions.p1.value_counts()
# Out:
# golden_retriever             150
# Labrador_retriever           100
# Pembroke                     89
# Chihuahua                    83
# pug                          57
# chow                         44
# Samoyed                      43
# toy_poodle                   39
# Pomeranian                   38
# malamute                     30
# cocker_spaniel               30
# French_bulldog               26
# miniature_pinscher           23
# Chesapeake_Bay_retriever     23
# seat_belt                    22
# German_shepherd              20
# Siberian_husky               20
# Staffordshire_bullterrier    20
# Cardigan                     19
# web_site                     19
# Eskimo_dog                   18
# Shetland_sheepdog            18
# beagle                       18
# teddy                        18
# Maltese_dog                  18
# Shih-Tzu                     17
# Lakeland_terrier             17
# Rottweiler                   17
# Italian_greyhound            16
# ...

# %%
# According to the p1-dog prediction whether there is a dog on the picture or not, there are 543 rows with no dog on the picture
# According to the p2-dog prediction whether there is a dog on the picture or not, there are 522 rows with no dog on the picture
# According to the p3-dog prediction whether there is a dog on the picture or not, there are 576 rows with no dog on the picture
# According to the p1-dog, p2-dog and p3-dog together, there are 324 rows with no dog on the picture
image_predictions[image_predictions['p1_dog'] == False].count()
image_predictions[image_predictions['p2_dog'] == False].count()
image_predictions[image_predictions['p3_dog'] == False].count()
image_predictions.query("p1_dog == False & p2_dog == False & p3_dog == False").count()
# Out:
# tweet_id    324
# jpg_url     324
# img_num     324
# p1          324
# p1_conf     324
# p1_dog      324
# p2          324
# p2_conf     324
# p2_dog      324
# p3          324
# p3_conf     324
# p3_dog      324
# dtype: int64

# %% [markdown]
# ##### tweet_info

# %%
tweet_info.head()
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193  7715           36240
# 1  892177421306343426  5701           31252
# 2  891815181378084864  3780           23536
# 3  891689557279858688  7876           39540
# 4  891327558926688256  8486           37761

# %%
tweet_info.tail()
# Out:
#                        id  retweet_count  favorite_count
# 14648  666049248165822465  39             96
# 14649  666044226329800704  132            272
# 14650  666033412701032449  41             112
# 14651  666029285002620928  42             121
# 14652  666020888022790149  462            2413

# %%
tweet_info.describe()
# Out:
#                  id  retweet_count  favorite_count
# count  1.465300e+04  14653.000000   14653.000000
# mean   7.461258e+17  2813.248209    7927.927796
# std    6.967600e+16  4659.041068    12072.593690
# min    6.660209e+17  1.000000       0.000000
# 25%    6.791488e+17  560.000000     1331.000000
# 50%    7.287512e+17  1357.000000    3422.000000
# 75%    8.065422e+17  3283.000000    10050.000000
# max    8.924206e+17  77882.000000   156359.000000

# %%
#Data types seems ok
tweet_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14653 entries, 0 to 14652
# Data columns (total 3 columns):
# id                14653 non-null int64
# retweet_count     14653 non-null int64
# favorite_count    14653 non-null int64
# dtypes: int64(3)
# memory usage: 343.5 KB

# %%
tweet_info['retweet_count'].nunique()
# Out:
# 3450

# %%
#tweet_info has duplicates 5631
tweet_info.duplicated().sum()
# Out:
# 5631

# %%
#No missing values
tweet_info.isnull().sum().sum()
# Out:
# 0

# %%
#Rename id to tweet_id and join tweet_info with df_tw_archive and image_predictions
#NaN id (tweet_id) in comparison to the df_tw_archive 
tweet_info['id'].count()
# Out:
# 14653

# %%
df_tw_archive['tweet_id'].count()
# Out:
# 2356

# %%
#NaN tweet_id in comparison to the df_tw_archive 
image_predictions['tweet_id'].count()
# Out:
# 2075

# %% [markdown]
# #### Quality Issues:
#
# df_tw_archive:
# 1.	Incorrect data type for  timestamp and retweeted_status_timestamp => Change to datetime
# 2.	Replace:  'O' to 'O'Malley'; 'Al' to 'Al Cabone';  'my' to 'Zoey'
# 3.  We want to have only original ratings (no retweets) that have images => Remove 'retweeted_status_id' is not  null and Remove columns 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'
# 4.	Column Name include invalid names "a", "an", "None", "the" etc. => Retrieve and Replace with the 'named' and 'name is' from 'text' col.
# 5.  If there are still 'None' missing values in 'name' => Change from 'None' to NaN.
# 6.  The columns rating_denominator and rating_numerator have invalid values:
#
# #313 13/10 second pos
# #1068 14/10 second pos
# #1165 13/10 second pos
# #1202 11/10 second pos
# #1662 10/10 second pos
# #2335 9/10 second pos
#
# => Correct positions where denominator is not 10 and where the text gives the correct rating by retrieving the second pos as a rating and change denominator and numerator correspondingly
#
#
# image_predictions:
# 7.	According to the p1-dog, p2-dog and p3-dog together, there are 324 rows with no dog on the picture => Delete 324 rows
# 8.	The p1,p2 and p3 include Uppercase and Lowercase for the first letter => Replace first letter with Uppercase
#
# tweet_info:
# 9.	Rename id to tweet_id
# 10.  Drop duplicates - 5631
#
#
# #### Tidiness Issues:
#
# df_tw_archive
# 1.	One column 'Stage'  : doggo, floofer, pupper, puppo  => Create a new variable – 'Stage'  to show the four dog stages, drop the four columns, and fill the empty with NaN.
#
# tweet_info:
# 2.	Join tweet_info with df_tw_archive and image_predictions

# %% [markdown]
# ### 3.Cleaning data

# %%
#Create copies of original DataFrames  
df_tw_archive_clean = df_tw_archive.copy()
image_predictions_clean = image_predictions.copy()
tweet_info_clean = tweet_info.copy()

# %% [markdown]
# ##### Define
#
# df_tw_archive_clean: Incorrect data type for timestamp and retweeted_status_timestamp => Change to datetime

# %% [markdown]
# ##### Code

# %%
df_tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df_tw_archive_clean['timestamp'] = pd.to_datetime(df_tw_archive_clean['timestamp'])
df_tw_archive_clean['retweeted_status_timestamp'] = pd.to_datetime(df_tw_archive_clean['retweeted_status_timestamp'])

# %% [markdown]
# ##### Test

# %%
df_tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null datetime64[ns]
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# ##### Define
#
# df_tw_archive_clean:  Replace 'O' to 'O'Malley'; 'Al' to 'Al Cabone'; 'my' to 'Zoey'

# %% [markdown]
# ##### Code

# %%
df_tw_archive_clean['name']= df_tw_archive_clean['name'].replace('O', 'O\'Malley') 
df_tw_archive_clean['name']= df_tw_archive_clean['name'].replace('Al', 'Al Cabone') 
df_tw_archive_clean['name']= df_tw_archive_clean['name'].replace('my', 'Zoey')

# %% [markdown]
# ##### Test

# %%
df_tw_archive_clean[df_tw_archive_clean['name'] == 'O']
df_tw_archive_clean[df_tw_archive_clean['name'] == 'O\'Malley']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 775  776201521193218049 NaN                    NaN
#
#               timestamp  \
# 775 2016-09-14 23:30:38
#
#                                                                                  source  \
# 775  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                       text  \
# 775  This is O'Malley. That is how he sleeps. Doesn't care what you think about it. 10/10 comfy af https://t.co/Pq150LeRaC
#
#      retweeted_status_id  retweeted_status_user_id retweeted_status_timestamp  \
# 775 NaN                  NaN                       NaT
#
#                                                        expanded_urls  \
# 775  https://twitter.com/dog_rates/status/776201521193218049/photo/1
#
#      rating_numerator  rating_denominator      name doggo floofer pupper puppo
# ...

# %%
df_tw_archive_clean[df_tw_archive_clean['name'] == 'Al Cabone']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 820  770414278348247044 NaN                    NaN
#
#               timestamp  \
# 820 2016-08-30 00:14:12
#
#                                                                                  source  \
# 820  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                             text  \
# 820  Meet Al Cabone. He's a gangsta puppa. Rather h*ckin ruthless. Shows no mercy sometimes. 11/10 pet w extreme caution https://t.co/OUwWbEKOUV
#
#      retweeted_status_id  retweeted_status_user_id retweeted_status_timestamp  \
# 820 NaN                  NaN                       NaT
#
#                                                        expanded_urls  \
# 820  https://twitter.com/dog_rates/status/770414278348247044/photo/1
#
# ...

# %%
df_tw_archive_clean[df_tw_archive_clean['name'] == 'Zoey']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 8     890609185150312448 NaN                    NaN
# 115   870374049280663552 NaN                    NaN
# 852   765395769549590528 NaN                    NaN
# 2141  669993076832759809 NaN                    NaN
#
#                timestamp  \
# 8    2017-07-27 16:25:51
# 115  2017-06-01 20:18:38
# 852  2016-08-16 03:52:26
# 2141 2015-11-26 21:36:12
#
#                                                                                   source  \
# 8     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 115   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 852   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2141  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %% [markdown]
# ##### Define
#
# df_tw_archive_clean:  We want to have only original ratings (no retweets) that have images => Remove 'retweeted_status_id' is not null and Remove columns 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'

# %% [markdown]
# ##### Code

# %%
df_tw_archive_clean = df_tw_archive_clean[df_tw_archive_clean['retweeted_status_id'].isnull()]

# %% [markdown]
# ##### Test

# %%
df_tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2175 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2175 non-null datetime64[ns]
# source                        2175 non-null object
# text                          2175 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null datetime64[ns]
# expanded_urls                 2117 non-null object
# rating_numerator              2175 non-null int64
# rating_denominator            2175 non-null int64
# name                          2175 non-null object
# doggo                         2175 non-null object
# floofer                       2175 non-null object
# pupper                        2175 non-null object
# ...

# %% [markdown]
# ##### Code

# %%
# Drop columns related to retweets
columns = ['retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp']
df_tw_archive_clean = df_tw_archive_clean.drop(columns, axis=1)

# %% [markdown]
# ##### Test

# %%
df_tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 14 columns):
# tweet_id                 2175 non-null int64
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2175 non-null datetime64[ns]
# source                   2175 non-null object
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_numerator         2175 non-null int64
# rating_denominator       2175 non-null int64
# name                     2175 non-null object
# doggo                    2175 non-null object
# floofer                  2175 non-null object
# pupper                   2175 non-null object
# puppo                    2175 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(8)
# memory usage: 254.9+ KB

# %% [markdown]
# ##### Define
#
# df_tw_archive_clean:  Column Name include invalid names "a", "an", "None", "the" etc. => Retrieve and Replace with the 'named' and 'name is' from 'text' col.

# %% [markdown]
# ##### Code

# %%
# Save locations where 'name' column is lowercase and 'text' column contains 'named' 
# Save locations where 'name' column is lowercase and 'text' column contains 'name is'
named_to_replace = df_tw_archive_clean.loc[(df_tw_archive_clean['name'].str.islower()) & (df_tw_archive_clean['text'].str.contains('named'))]
name_is_to_replace = df_tw_archive_clean.loc[(df_tw_archive_clean['name'].str.islower()) & (df_tw_archive_clean['text'].str.contains('name is'))]
not_named_to_replace = df_tw_archive_clean.loc[(df_tw_archive_clean['name'].str.islower())]

# %%
# Save these locations as lists
named_to_replace_list = named_to_replace['text'].tolist()
name_is_to_replace_list = name_is_to_replace['text'].tolist()
not_named_to_replace_list = not_named_to_replace['text'].tolist()

# %%
for entry in named_to_replace_list:
    mask = df_tw_archive_clean.text == entry
    name_column = 'name'
    df_tw_archive_clean.loc[mask, name_column] = re.findall(r"named\s(\w+)", entry)

# %%
for entry in name_is_to_replace_list:
    mask = df_tw_archive_clean.text == entry
    name_column = 'name'
    df_tw_archive_clean.loc[mask, name_column] = re.findall(r"name is\s(\w+)", entry)

# %%
for entry in not_named_to_replace_list:
    mask = df_tw_archive_clean.text == entry
    name_column = 'name'
    df_tw_archive_clean.loc[mask, name_column] = "None"

# %% [markdown]
# ##### Test

# %%
df_tw_archive_clean.name.sort_values()
# Out:
# 1035    Abby
# 1021    Abby
# 938     Ace
# 1933    Acro
# 1327    Adele
# 1934    Aiden
# 77      Aja
# 480     Akumi
# 820     Al Cabone
# 1954    Albert
# 875     Albert
# 144     Albus
# 412     Albus
# 1115    Aldrick
# 2046    Alejandro
# 374     Alexander
# 1189    Alexanderson
# 486     Alf
# 2238    Alfie
# 1616    Alfie
# 367     Alfie
# 858     Alfie
# 51      Alfy
# 201     Alice
# 1701    Alice
# 1495    Amber
# 1334    Ambrose
# 2078    Amy
# 2195    Amélie
# 780     Anakin
#          ...
# 280     Winston
# 1243    Winston
# 559     Winston
# 1829    Winston
# 2133    Winston
# 407     Winston
# 816     Winston
# 986     Winston
# 877     Wishes
# 1451    Wyatt
# 174     Wyatt
# 410     Wyatt
# 1378    Yoda
# 43      Yogi
# 622     Yogi
# 1409    Yukon
# 1332    Zara
# 2206    Zeek
# 17      Zeke
# 547     Zeke
# 181     Zeke
# 1210    Zeus
# 1124    Ziva
# 966     Zoe
# 2141    Zoey
# 852     Zoey
# 8       Zoey
# 115     Zoey
# 151     Zooey
# 1875    Zuzu
# ...

# %%
df_tw_archive_clean[df_tw_archive_clean['name'] == 'None']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856 NaN                    NaN
# 7     890729181411237888 NaN                    NaN
# 12    889665388333682689 NaN                    NaN
# 22    887517139158093824 NaN                    NaN
# 24    887343217045368832 NaN                    NaN
# 25    887101392804085760 NaN                    NaN
# 30    886267009285017600  8.862664e+17           2.281182e+09
# 35    885518971528720385 NaN                    NaN
# 37    885167619883638784 NaN                    NaN
# 41    884441805382717440 NaN                    NaN
# 42    884247878851493888 NaN                    NaN
# 47    883117836046086144 NaN                    NaN
# 55    881633300179243008  8.816070e+17           4.738443e+07
# 56    881536004380872706 NaN                    NaN
# 59    880872448815771648 NaN                    NaN
# 62    880095782870896641 NaN                    NaN
# ...

# %% [markdown]
# ##### Define
#
# Change from 'None'  missing values in 'name' to NaN

# %% [markdown]
# ##### Code

# %%
df_tw_archive_clean['name'] = df_tw_archive_clean['name'].replace('None', np.NaN)

# %% [markdown]
# ##### Test

# %%
df_tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 14 columns):
# tweet_id                 2175 non-null int64
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2175 non-null datetime64[ns]
# source                   2175 non-null object
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_numerator         2175 non-null int64
# rating_denominator       2175 non-null int64
# name                     1392 non-null object
# doggo                    2175 non-null object
# floofer                  2175 non-null object
# pupper                   2175 non-null object
# puppo                    2175 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(8)
# memory usage: 254.9+ KB

# %%
df_tw_archive_clean[df_tw_archive_clean['name'] == 'None']
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ##### Define
#
# df_tw_archive_clean:  The columns rating_denominator and rating_numerator have invalid values => Correct positions where denominator is not 10 and where the text gives the correct rating

# %% [markdown]
# ##### Code

# %%
df_tw_archive_clean[df_tw_archive_clean['rating_denominator'] != 10].count()
# Out:
# tweet_id                 22
# in_reply_to_status_id    5
# in_reply_to_user_id      5
# timestamp                22
# source                   22
# text                     22
# expanded_urls            18
# rating_numerator         22
# rating_denominator       22
# name                     3
# doggo                    22
# floofer                  22
# pupper                   22
# puppo                    22
# dtype: int64

# %%
pd.set_option('display.max_colwidth', -1)

# %%
# Save the text where the rating numerator and denominators were incorrectly extracted
ratings_to_fix = ['@jonnysun @Lin_Manuel ok jomny I know you\'re excited but 960/00 isn\'t a valid rating, 13/10 is tho', 'After so many requests, this is Bretagne. She was the last surviving 9/11 search dog, and our second ever 14/10. RIP https://t.co/XAVDNDaVgQ', 
 'Happy 4/20 from the squad! 13/10 for all https://t.co/eV1diwds8a', 
 'This is Bluebert. He just saw that both #FinalFur match ups are split 50/50. Amazed af. 11/10 https://t.co/Kky1DPG4iq', 
 'This is Darrel. He just robbed a 7/11 and is in a high speed police chase. Was just spotted by the helicopter 10/10 https://t.co/7EsP8LmSp5',
 'This is an Albanian 3 1/2 legged  Episcopalian. Loves well-polished hardwood flooring. Penis on the collar. 9/10 https://t.co/d9NcXFKwLv']

# %%
# Loop through the list of ratings to fix and extract the second occurence of #/ to save as the rating numerator. As all the
# occurences of the actual ratings in the ratings to fix list have a denominator of 10, we will set that value for each 
#entry instead of extracting it.
for entry in ratings_to_fix:
    mask = df_tw_archive_clean.text == entry
    column_name1 = 'rating_numerator'
    column_name2 = 'rating_denominator'
    df_tw_archive_clean.loc[mask, column_name1] = re.findall(r"\d+\.?\d*\/\d+\.?\d*\D+(\d+\.?\d*)\/\d+\.?\d*", entry)
    df_tw_archive_clean.loc[mask, column_name2] = 10

# %% [markdown]
# ##### Test

# %%
df_tw_archive_clean[df_tw_archive_clean.text.isin(ratings_to_fix)]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640  8.352460e+17           26259576.0
# 1068  740373189193256964 NaN                    NaN
# 1165  722974582966214656 NaN                    NaN
# 1202  716439118184652801 NaN                    NaN
# 1662  682962037429899265 NaN                    NaN
# 2335  666287406224695296 NaN                    NaN
#
#                timestamp  \
# 313  2017-02-24 21:54:03
# 1068 2016-06-08 02:41:38
# 1165 2016-04-21 02:25:47
# 1202 2016-04-03 01:36:11
# 1662 2016-01-01 16:30:13
# 2335 2015-11-16 16:11:11
#
#                                                                                   source  \
# 313   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1068  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1165  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# ##### Define
#
# tweet_info:  rename id to tweet_id

# %% [markdown]
# ##### Code

# %%
tweet_info_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14653 entries, 0 to 14652
# Data columns (total 3 columns):
# id                14653 non-null int64
# retweet_count     14653 non-null int64
# favorite_count    14653 non-null int64
# dtypes: int64(3)
# memory usage: 343.5 KB

# %%
tweet_info_clean.rename(columns={'id': 'tweet_id'}, inplace=True)

# %% [markdown]
# ##### Test

# %%
tweet_info_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14653 entries, 0 to 14652
# Data columns (total 3 columns):
# tweet_id          14653 non-null int64
# retweet_count     14653 non-null int64
# favorite_count    14653 non-null int64
# dtypes: int64(3)
# memory usage: 343.5 KB

# %% [markdown]
# ##### Define
#
# tweet_info_clean: Drop duplicates - 5631

# %% [markdown]
# ##### Code

# %%
tweet_info_clean = tweet_info_clean.drop_duplicates()

# %% [markdown]
# ##### Test

# %%
tweet_info_clean.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Define
#
# image_predictions:  According to the p1-dog, p2-dog and p3-dog together, there are 324 rows with no dog on the picture => Delete 324 rows

# %% [markdown]
# ##### Code

# %%
image_predictions_clean = image_predictions.copy()
image_predictions_clean.query("p1_dog == False & p2_dog == False & p3_dog == False")
# Out:
#                 tweet_id  \
# 6     666051853826850816
# 17    666104133288665088
# 18    666268910803644416
# 21    666293911632134144
# 25    666362758909284353
# 29    666411507551481857
# 45    666786068205871104
# 50    666837028449972224
# 51    666983947667116034
# 53    667012601033924608
# 56    667065535570550784
# 69    667188689915760640
# 73    667369227918143488
# 77    667437278097252352
# 78    667443425659232256
# 93    667549055577362432
# 94    667550882905632768
# 96    667724302356258817
# 98    667766675769573376
# 100   667782464991965184
# 106   667866724293877760
# 107   667873844930215936
# 112   667911425562669056
# 115   667937095915278337
# 117   668142349051129856
# 118   668154635664932864
# 123   668226093875376128
# 130   668291999406125056
# 132   668466899341221888
# 140   668544745690562560
# ...                  ...
# 1839  837482249356513284
# 1844  838916489579200512
# 1847  839290600511926273
# 1851  840370681858686976
# ...

# %%
image_predictions_clean = image_predictions_clean.drop(image_predictions_clean[(image_predictions_clean.p1_dog == False) & (image_predictions_clean.p2_dog == False) & (image_predictions_clean.p3_dog == False)].index)

# %% [markdown]
# ##### Test

# %%
image_predictions_clean.query("p1_dog == False & p2_dog == False & p3_dog == False").count()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %% [markdown]
# ##### Define
#
# image_predictions: The p1,p2 and p3 include Uppercase and Lowercase for the first letter => Replace first letter with Uppercase

# %% [markdown]
# ##### Code

# %%
image_predictions_clean['p1'] = image_predictions_clean['p1'].str.capitalize()
image_predictions_clean['p2'] = image_predictions_clean['p2'].str.capitalize()
image_predictions_clean['p3'] = image_predictions_clean['p3'].str.capitalize()

# %% [markdown]
# ##### Test

# %%
image_predictions_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0  1        Welsh_springer_spaniel  0.465074  True    Collie
# 1  1        Redbone                 0.506826  True    Miniature_pinscher
# 2  1        German_shepherd         0.596461  True    Malinois
# 3  1        Rhodesian_ridgeback     0.408143  True    Redbone
# 4  1        Miniature_pinscher      0.560311  True    Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665  True    Shetland_sheepdog    0.061428  True
# ...

# %% [markdown]
# #### Tidiness Issues:
#
# ##### Define
#
# df_tw_archive:  One column 'Stage' : doggo, floofer, pupper, puppo => Create a new variable – ‘Stage‘ to show the four dog stages, drop the four columns, and fill the empty with NaN

# %% [markdown]
# ###### Code

# %%
df_tw_archive_clean['doggo'].unique()
# Out:
# array(['None', 'doggo'], dtype=object)

# %%
df_tw_archive_clean['floofer'].unique()
# Out:
# array(['None', 'floofer'], dtype=object)

# %%
df_tw_archive_clean['pupper'].unique()
# Out:
# array(['None', 'pupper'], dtype=object)

# %%
df_tw_archive_clean['puppo'].unique()
# Out:
# array(['None', 'puppo'], dtype=object)

# %%
df_tw_archive_clean[df_tw_archive_clean['doggo'] == 'None'].head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193 NaN                    NaN
# 1  892177421306343426 NaN                    NaN
# 2  891815181378084864 NaN                    NaN
# 3  891689557279858688 NaN                    NaN
# 4  891327558926688256 NaN                    NaN
#
#             timestamp  \
# 0 2017-08-01 16:23:56
# 1 2017-08-01 00:17:27
# 2 2017-07-31 00:18:03
# 3 2017-07-30 15:58:51
# 4 2017-07-29 16:00:24
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
# replace all the 'None' before cat
stage = ['doggo','pupper', 'floofer', 'puppo' ]
for i in stage:
        df_tw_archive_clean[i] = df_tw_archive_clean[i].replace('None', '')

# %%
df_tw_archive_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193 NaN                    NaN
# 1  892177421306343426 NaN                    NaN
# 2  891815181378084864 NaN                    NaN
# 3  891689557279858688 NaN                    NaN
# 4  891327558926688256 NaN                    NaN
#
#             timestamp  \
# 0 2017-08-01 16:23:56
# 1 2017-08-01 00:17:27
# 2 2017-07-31 00:18:03
# 3 2017-07-30 15:58:51
# 4 2017-07-29 16:00:24
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
# use cat to combine 
df_tw_archive_clean['stage'] = df_tw_archive_clean.doggo.str.cat(df_tw_archive_clean.floofer).str.cat(df_tw_archive_clean.pupper).str.cat(df_tw_archive_clean.puppo)

# %%
# drop the four old colomns
df_tw_archive_clean = df_tw_archive_clean.drop(['doggo','floofer','pupper','puppo'], axis = 1)

# %%
# use np.nan to fill the empty
df_tw_archive_clean['stage'] = df_tw_archive_clean['stage'].replace('', np.nan)

# %% [markdown]
# ###### Test

# %%
df_tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 11 columns):
# tweet_id                 2175 non-null int64
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2175 non-null datetime64[ns]
# source                   2175 non-null object
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_numerator         2175 non-null object
# rating_denominator       2175 non-null int64
# name                     1392 non-null object
# stage                    344 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 203.9+ KB

# %%
# We have invalid values for dog stage as doggopupper - 10; doggofloofer-1; doggopuppo-1
# Additional Assesment and Cleaning based ión the text
df_tw_archive_clean['stage'].value_counts()
# Out:
# pupper          224
# doggo           75
# puppo           24
# doggopupper     10
# floofer         9
# doggofloofer    1
# doggopuppo      1
# Name: stage, dtype: int64

# %% [markdown]
# ##### Additional Assessment
#
# invalid values for dog stage as doggopupper - 10; doggofloofer-1; doggopuppo-1

# %%
df_tw_archive_clean[df_tw_archive_clean['stage'] == 'doggopupper'].count()
# Out:
# tweet_id                 10
# in_reply_to_status_id    1
# in_reply_to_user_id      1
# timestamp                10
# source                   10
# text                     10
# expanded_urls            10
# rating_numerator         10
# rating_denominator       10
# name                     4
# stage                    10
# dtype: int64

# %%
#There are some NaN in Names which are not specified whether it is doggo or pupper => rename doggopupper to np.nan
# 4 values with the Name are specified => change to a correct dog stage
pd.set_option('display.max_colwidth', -1)
df_tw_archive_clean[df_tw_archive_clean['stage'] == 'doggopupper']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 460   817777686764523521 NaN                    NaN
# 531   808106460588765185 NaN                    NaN
# 565   802265048156610565  7.331095e+17           4.196984e+09
# 575   801115127852503040 NaN                    NaN
# 705   785639753186217984 NaN                    NaN
# 733   781308096455073793 NaN                    NaN
# 889   759793422261743616 NaN                    NaN
# 956   751583847268179968 NaN                    NaN
# 1063  741067306818797568 NaN                    NaN
# 1113  733109485275860992 NaN                    NaN
#
#                timestamp  \
# 460  2017-01-07 16:59:28
# 531  2016-12-12 00:29:28
# 565  2016-11-25 21:37:47
# 575  2016-11-22 17:28:25
# 705  2016-10-11 00:34:48
# 733  2016-09-29 01:42:20
# 889  2016-07-31 16:50:42
# 956  2016-07-09 01:08:47
# 1063 2016-06-10 00:39:48
# 1113 2016-05-19 01:38:16
#
# ...

# %%
# doggofloofer is actually floofer  
df_tw_archive_clean[df_tw_archive_clean['stage'] == 'doggofloofer']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 200  854010172552949760 NaN                    NaN
#
#               timestamp  \
# 200 2017-04-17 16:34:26
#
#                                                                                  source  \
# 200  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                      text  \
# 200  At first I thought this was a shy doggo, but it's actually a Rare Canadian Floofer Owl. Amateurs would confuse the two. 11/10 only send dogs https://t.co/TXdT3tmuYk
#
#                                                                                                                        expanded_urls  \
# 200  https://twitter.com/dog_rates/status/854010172552949760/photo/1,https://twitter.com/dog_rates/status/854010172552949760/photo/1
#
# ...

# %%
# doggopuppo is actually puppo
df_tw_archive_clean[df_tw_archive_clean['stage'] == 'doggopuppo']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 191  855851453814013952 NaN                    NaN
#
#               timestamp  \
# 191 2017-04-22 18:31:02
#
#                                                                                  source  \
# 191  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                text  \
# 191  Here's a puppo participating in the #ScienceMarch. Cleverly disguising her own doggo agenda. 13/10 would keep the planet habitable for https://t.co/cMhq16isel
#
#                                                        expanded_urls  \
# 191  https://twitter.com/dog_rates/status/855851453814013952/photo/1
#
#     rating_numerator  rating_denominator name       stage
# 191  13               10                  NaN  doggopuppo

# %% [markdown]
# ##### Additional - Define
#
# There are some NaN in Names which are not specified whether it is doggo or pupper => rename doggopupper to np.nan

# %% [markdown]
# ##### Code

# %%
df_tw_archive_clean.loc[(df_tw_archive_clean['name'].isnull()) & (df_tw_archive_clean.stage == 'doggopupper'), 'stage']='None'

# %% [markdown]
# ##### Test

# %%
# There are only 4 left with Names
df_tw_archive_clean[df_tw_archive_clean['stage'] == 'doggopupper']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 460  817777686764523521 NaN                    NaN
# 575  801115127852503040 NaN                    NaN
# 705  785639753186217984 NaN                    NaN
# 889  759793422261743616 NaN                    NaN
#
#               timestamp  \
# 460 2017-01-07 16:59:28
# 575 2016-11-22 17:28:25
# 705 2016-10-11 00:34:48
# 889 2016-07-31 16:50:42
#
#                                                                                  source  \
# 460  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 575  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 705  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 889  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %% [markdown]
# ##### Additional - Define
#
# Rename tweet_id - stage:
#
# 1. 854010172552949760        -  doggofloofer to  floofer
# 2. 855851453814013952        -  doggopuppo to puppo
# 3. 817777686764523521 Dido   -  doggopupper to pupper
# 4. 801115127852503040 Bones  -  doggopupper to pupper
# 5. 785639753186217984 Pinot  -  doggopupper to doggo
# 6. 759793422261743616 Maggie -  doggopupper to doggo

# %% [markdown]
# ##### Code

# %%
# 854010172552949760        -  doggofloofer to  floofer  
# 855851453814013952        -  doggopuppo to puppo
# 817777686764523521 Dido   -  doggopupper to pupper
# 801115127852503040 Bones  -  doggopupper to pupper
# 785639753186217984 Pinot  -  doggopupper to doggo
# 759793422261743616 Maggie -  doggopupper to doggo

df_tw_archive_clean.loc[df_tw_archive_clean.tweet_id == 854010172552949760, 'stage'] = 'floofer'
df_tw_archive_clean.loc[df_tw_archive_clean.tweet_id == 855851453814013952, 'stage'] = 'puppo'
df_tw_archive_clean.loc[df_tw_archive_clean.tweet_id == 817777686764523521, 'stage'] = 'pupper'
df_tw_archive_clean.loc[df_tw_archive_clean.tweet_id == 801115127852503040, 'stage'] = 'pupper'
df_tw_archive_clean.loc[df_tw_archive_clean.tweet_id == 785639753186217984, 'stage'] = 'doggo'
df_tw_archive_clean.loc[df_tw_archive_clean.tweet_id == 759793422261743616, 'stage'] = 'doggo'

# %% [markdown]
# ##### Test

# %%
df_tw_archive_clean['stage'].value_counts()
# Out:
# pupper     226
# doggo      77
# puppo      25
# floofer    10
# None       6
# Name: stage, dtype: int64

# %% [markdown]
# ##### Define
#
# tweet_info: Join tweet_info with df_tw_archive and image_predictions

# %% [markdown]
# ##### Code

# %%
# join two tables on 'tweet_id' and use inner join method
df_tw_archive_clean = pd.merge(df_tw_archive_clean, tweet_info_clean, on='tweet_id', how = 'inner')

# %%
df_tw_archive_clean = pd.merge(df_tw_archive_clean, image_predictions_clean, on='tweet_id', how = 'inner')

# %% [markdown]
# ##### Test

# %%
df_tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6667 entries, 0 to 6666
# Data columns (total 24 columns):
# tweet_id                 6667 non-null int64
# in_reply_to_status_id    83 non-null float64
# in_reply_to_user_id      83 non-null float64
# timestamp                6667 non-null datetime64[ns]
# source                   6667 non-null object
# text                     6667 non-null object
# expanded_urls            6667 non-null object
# rating_numerator         6667 non-null object
# rating_denominator       6667 non-null int64
# name                     4775 non-null object
# stage                    1130 non-null object
# retweet_count            6667 non-null int64
# favorite_count           6667 non-null int64
# jpg_url                  6667 non-null object
# img_num                  6667 non-null int64
# p1                       6667 non-null object
# p1_conf                  6667 non-null float64
# p1_dog                   6667 non-null bool
# ...

# %% [markdown]
# ##### Final Tests

# %%
df_tw_archive_clean.head(2)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892177421306343426 NaN                    NaN
# 1  892177421306343426 NaN                    NaN
#
#             timestamp  \
# 0 2017-08-01 00:17:27
# 1 2017-08-01 00:17:27
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                  text  \
# 0  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
# ...

# %%
df_tw_archive_clean.isnull().sum()
# Out:
# tweet_id                 0
# in_reply_to_status_id    6584
# in_reply_to_user_id      6584
# timestamp                0
# source                   0
# text                     0
# expanded_urls            0
# rating_numerator         0
# rating_denominator       0
# name                     1892
# stage                    5537
# retweet_count            0
# favorite_count           0
# jpg_url                  0
# img_num                  0
# p1                       0
# p1_conf                  0
# p1_dog                   0
# p2                       0
# p2_conf                  0
# p2_dog                   0
# p3                       0
# p3_conf                  0
# p3_dog                   0
# dtype: int64

# %%
df_tw_archive_clean['in_reply_to_status_id'] = df_tw_archive_clean['in_reply_to_status_id'].replace('', np.nan)
df_tw_archive_clean['in_reply_to_user_id'] = df_tw_archive_clean['in_reply_to_user_id'].replace('', np.nan)
df_tw_archive_clean['name'] = df_tw_archive_clean['name'].replace('', np.nan)

# %%
df_tw_archive_clean.duplicated().sum()
# Out:
# 0

# %%
df_tw_archive_clean.head(2)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892177421306343426 NaN                    NaN
# 1  892177421306343426 NaN                    NaN
#
#             timestamp  \
# 0 2017-08-01 00:17:27
# 1 2017-08-01 00:17:27
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                  text  \
# 0  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
# ...

# %% [markdown]
# ##### II. Storing, analyzing, and visualizing the wrangled data

# %%
df_tw_archive_clean.to_csv('twitter_archive_master.csv', encoding='utf-8')

# %% [markdown]
# ##### Analyze and Visualize

# %% [markdown]
# 1. The most popular dog stage
# 2. The most populat breed of a dog
# 3. The most favourited/retweeted tweet
# 4. The correlation between ‘retweet_count’ and ‘favorite_count’.

# %%
df_tw_archive_clean.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'stage', 'retweet_count',
#        'favorite_count', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %% [markdown]
# #####  The most popular dog stage

# %%
df_tw_archive_clean['stage'].value_counts()
# Out:
# pupper     710
# doggo      259
# puppo      97
# floofer    38
# None       26
# Name: stage, dtype: int64

# %%
p = 710 / df_tw_archive_clean.stage.value_counts().sum() *100
d = 259 / df_tw_archive_clean.stage.value_counts().sum() *100
po = 97 / df_tw_archive_clean.stage.value_counts().sum() *100
f = 38 / df_tw_archive_clean.stage.value_counts().sum() *100

labels = 'pupper', 'doggo',  'puppo', 'floofer'
sizes = [p, d, po , f]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', pctdistance=1.2, labeldistance=1.4, shadow=True, startangle=90)
ax1.axis('equal')


plt.ylabel('Dog Stages', fontsize=12)
plt.title('The Distribution of Dog Stages', y=1.2, loc='left', fontsize=14)


plt.show()

# %% [markdown]
# The most popular dog stage is pupper with 64,3%. The list popular is floofer with 3,4%

# %% [markdown]
# ##### The most populat breed of a dog

# %% [markdown]
# First I will compare three predictions and choose the one which have better model

# %%
sns.set(style='darkgrid')
ax = sns.distplot(df_tw_archive_clean['p1_conf'])

# %%
sns.set(style='darkgrid')
sorted_p1 = df_tw_archive_clean['p1_dog'].value_counts()
plt.pie(sorted_p1, labels = sorted_p1.index, startangle = 90, counterclock = False,
       wedgeprops = {'width': 0.6})
plt.axis('square')
# Out:
# (-1.1070975109261258,
#  1.1066313703018746,
#  -1.104565564730277,
#  1.1091633164977235)

# %%
sns.set(style='whitegrid')
ax = sns.distplot(df_tw_archive_clean['p2_conf'])

# %%
sns.set(style='darkgrid')
sorted_p1 = df_tw_archive_clean['p2_dog'].value_counts()
plt.pie(sorted_p1, labels = sorted_p1.index, startangle = 90, counterclock = False,
       wedgeprops = {'width': 0.6})
plt.axis('square')
# Out:
# (-1.1062579076624839,
#  1.1058282543106117,
#  -1.1010115811805703,
#  1.1110745807925253)

# %%
sns.set(style='ticks')
ax = sns.distplot(df_tw_archive_clean['p3_conf'])

# %%
sns.set(style='darkgrid')
sorted_p1 = df_tw_archive_clean['p3_dog'].value_counts()
plt.pie(sorted_p1, labels = sorted_p1.index, startangle = 90, counterclock = False,
       wedgeprops = {'width': 0.6})
plt.axis('square')
# Out:
# (-1.1019918877534673,
#  1.1066436660397378,
#  -1.1065190917363077,
#  1.1021164620568975)

# %% [markdown]
# According to the graphs above, the first prediction of the dog breed has most of the cases 100%.

# %%
df_b = df_tw_archive_clean.p1.value_counts().head(5)
df_b
# Out:
# Golden_retriever      597
# Pembroke              385
# Labrador_retriever    384
# Chihuahua             291
# Pug                   207
# Name: p1, dtype: int64

# %%
df_b.plot(kind = 'bar')
plt.xlabel('Dog Breed', y=1.2, fontsize=12)
plt.ylabel('Count',  fontsize=12)
plt.title('The Distribution of Dog Breeds', y=1.1, loc='center', fontsize=14)
# Out:
# Text(0.5,1.1,'The Distribution of Dog Breeds')

# %% [markdown]
# According to the first prediciton, the most popular dog breed is the Golden Retriever

# %% [markdown]
# ##### The most favourited/retweeted tweet

# %%
# Labrador_retriever with all top 5  favorite_counts 
pd.set_option('display.max_columns', 500)
df_tw_archive_clean.sort_values(by = 'favorite_count', ascending = False).head(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 3292  744234799360020481 NaN                    NaN
# 3296  744234799360020481 NaN                    NaN
# 3293  744234799360020481 NaN                    NaN
# 3294  744234799360020481 NaN                    NaN
# 3295  744234799360020481 NaN                    NaN
#
#                timestamp  \
# 3292 2016-06-18 18:26:18
# 3296 2016-06-18 18:26:18
# 3293 2016-06-18 18:26:18
# 3294 2016-06-18 18:26:18
# 3295 2016-06-18 18:26:18
#
#                                                                                   source  \
# 3292  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3296  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3293  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3294  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
# Labrador_retriever with all top 5  retweet_counts
pd.set_option('display.max_columns', 500)
df_tw_archive_clean.sort_values(by = 'retweet_count', ascending = False).head(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 3292  744234799360020481 NaN                    NaN
# 3293  744234799360020481 NaN                    NaN
# 3294  744234799360020481 NaN                    NaN
# 3296  744234799360020481 NaN                    NaN
# 3295  744234799360020481 NaN                    NaN
#
#                timestamp  \
# 3292 2016-06-18 18:26:18
# 3293 2016-06-18 18:26:18
# 3294 2016-06-18 18:26:18
# 3296 2016-06-18 18:26:18
# 3295 2016-06-18 18:26:18
#
#                                                                                   source  \
# 3292  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3293  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3294  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3296  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# Even though the Labrador_retriever is third most popular breed, but it on the top 5 most favourite/retweeted tweets

# %% [markdown]
# ##### The correlation between ‘retweet_count’ and ‘favorite_count’

# %%
df_tw_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6667 entries, 0 to 6666
# Data columns (total 24 columns):
# tweet_id                 6667 non-null int64
# in_reply_to_status_id    83 non-null float64
# in_reply_to_user_id      83 non-null float64
# timestamp                6667 non-null datetime64[ns]
# source                   6667 non-null object
# text                     6667 non-null object
# expanded_urls            6667 non-null object
# rating_numerator         6667 non-null object
# rating_denominator       6667 non-null int64
# name                     4775 non-null object
# stage                    1130 non-null object
# retweet_count            6667 non-null int64
# favorite_count           6667 non-null int64
# jpg_url                  6667 non-null object
# img_num                  6667 non-null int64
# p1                       6667 non-null object
# p1_conf                  6667 non-null float64
# p1_dog                   6667 non-null bool
# ...

# %%
# retweet_count` is positively correlates with `favorite_count` : r^2 = 0.928436
df_tw_archive_clean.corr(method='pearson')
# Out:
#                        tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# tweet_id               1.000000  0.702834              NaN
# in_reply_to_status_id  0.702834  1.000000              NaN
# in_reply_to_user_id   NaN       NaN                    NaN
# rating_denominator    -0.036305 -0.039163              NaN
# retweet_count          0.325885  0.257029              NaN
# favorite_count         0.563016  0.692126              NaN
# img_num                0.169315  0.130699              NaN
# p1_conf                0.096295  0.422265              NaN
# p1_dog                 0.073861 -0.021560              NaN
# p2_conf                0.008447 -0.503546              NaN
# p2_dog                 0.077314 -0.189069              NaN
# p3_conf               -0.029988 -0.308266              NaN
# p3_dog                 0.036534  0.281684              NaN
#
#                        rating_denominator  retweet_count  favorite_count  \
# ...

# %%
plt.figure(figsize = (14, 12))

plt.xscale('log')
plt.yscale('log')
plt.xlim(df_tw_archive_clean['favorite_count'].min() - 10, df_tw_archive_clean['favorite_count'].max() + 100000)
plt.ylim(10, df_tw_archive_clean['retweet_count'].max() + 25000)


plt.scatter(df_tw_archive_clean['favorite_count'], df_tw_archive_clean['retweet_count'], 
            c = 'blue', s = markers, edgecolor = 'None', alpha = 0.6)

# title and labels

plt.title('Favorite Count vs. Retweet Count', fontsize = 14)
plt.xlabel('Favorite Count', fontsize = 14)
plt.ylabel('Retweet Count', fontsize = 14)

plt.show()

# %% [markdown]
# The hypothesis is that most popular tweets usually get a large number of retweets and favorite counts.
#
# According to the test, the correlation between ‘retweet_count’ and ‘favorite_count’ has a strong positive relationship with the pearson r^2 is 0.928436.
#
# The plot confirms the hypothesis.

# %% [markdown]
# ##### Conclusion
#
# Based on the data, the Retrievers at the pupper and doggo stages are likely to get the better ratings.

# %% [markdown]
# ##### References:
#
# 1. https://kanoki.org/2019/11/12/how-to-use-regex-in-pandas/  -How to use Regex in Pandas
# 2. https://stackoverflow.com/questions/13851535/delete-rows-from-a-pandas-dataframe-based-on-a-conditional-expression-involving - How to delete rows from a pandas DataFrame based on a conditional expression
# 3. https://www.geeksforgeeks.org/split-a-string-into-columns-using-regex-in-pandas-dataframe/  - Split a String into columns using regex in pandas DataFrame
# 4. https://stackoverflow.com/questions/21943688/replace-nans-in-one-column-with-string-based-on-value-in-another-column - Replace NaN's in one column with string, based on value in another column
